# %% [markdown]
# Connected to dsd (Python 3.10.6)

# %%
import time
import requests
from lxml import html
import pandas as pd
from selenium import webdriver

def get_page_content(url, wait_time=10):
    # Utiliser Selenium pour laisser le temps à la page de charger
    driver = webdriver.Chrome()
    driver.get(url)

    # Attendre que la page se charge
    time.sleep(wait_time)

    # Utiliser requests pour obtenir le contenu de la page après le chargement
    page_content = driver.page_source

    # Fermer le navigateur Selenium
    driver.quit()

    return page_content

def scrape_return_stats(year):
    # Construire l'URL avec l'année spécifiée
    url = f'https://www.atptour.com/en/stats/leaderboard?boardType=return&timeFrame={year}&surface=all&versusRank=all&formerNo1=false'

    # Obtenir le contenu de la page
    content = get_page_content(url)

    # Utiliser lxml pour créer un objet ElementTree à partir du contenu de la page
    tree = html.fromstring(content)

    # Utiliser l'XPath pour extraire le tableau
    table = tree.xpath('//div[@id="statsListingTableContent"]/table')[0]



     data = []
    for row in table.xpath('.//tbody//tr'):
        # Extraire le nom du joueur à partir du lien
        player_name = row.xpath('.//td[@data-title="Player"]//a[@class="stats-player-name"]/text()')[0].strip()
        
        # Extraire les autres données de la ligne
        row_data = [player_name] + [td.text.strip() if td.text else '' for td in row.xpath('.//td')[1:]]  # Ajouter le nom du joueur en première colonne
        print("Row data:", row_data)
        data.append(row_data)

    # Créer un DataFrame Pandas
    df = pd.DataFrame(data, columns=headers)



    return df

# Utilisation de la fonction pour l'année 2022
scrape_return_stats(2022)
# Out:
#   Cell In[1], line 38
#     data = []
#     ^
# IndentationError: unexpected indent

# %%
import time
import requests
from lxml import html
import pandas as pd
from selenium import webdriver

def get_page_content(url, wait_time=10):
    # Utiliser Selenium pour laisser le temps à la page de charger
    driver = webdriver.Chrome()
    driver.get(url)

    # Attendre que la page se charge
    time.sleep(wait_time)

    # Utiliser requests pour obtenir le contenu de la page après le chargement
    page_content = driver.page_source

    # Fermer le navigateur Selenium
    driver.quit()

    return page_content

def scrape_return_stats(year):
    # Construire l'URL avec l'année spécifiée
    url = f'https://www.atptour.com/en/stats/leaderboard?boardType=return&timeFrame={year}&surface=all&versusRank=all&formerNo1=false'

    # Obtenir le contenu de la page
    content = get_page_content(url)

    # Utiliser lxml pour créer un objet ElementTree à partir du contenu de la page
    tree = html.fromstring(content)

    # Utiliser l'XPath pour extraire le tableau
    table = tree.xpath('//div[@id="statsListingTableContent"]/table')[0]



    data = []
    for row in table.xpath('.//tbody//tr'):
        # Extraire le nom du joueur à partir du lien
        player_name = row.xpath('.//td[@data-title="Player"]//a[@class="stats-player-name"]/text()')[0].strip()
        
        # Extraire les autres données de la ligne
        row_data = [player_name] + [td.text.strip() if td.text else '' for td in row.xpath('.//td')[1:]]  # Ajouter le nom du joueur en première colonne
        print("Row data:", row_data)
        data.append(row_data)

    # Créer un DataFrame Pandas
    df = pd.DataFrame(data, columns=headers)



    return df

# Utilisation de la fonction pour l'année 2022
scrape_return_stats(2022)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /henrifabre123/tennisML/scrapping/scraphenri.py in line 56
#      <a href='vscode-vfs://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a2264617461227d7d/henrifabre123/tennisML/scrapping/scraphenri.py?line=52'>53</a>     return df
#      <a href='vscode-vfs://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a2264617461227d7d/henrifabre123/tennisML/scrapping/scraphenri.py?line=54'>55</a> # Utilisation de la fonction pour l'année 2022
# ---> <a href='vscode-vfs://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a2264617461227d7d/henrifabre123/tennisML/scrapping/scraphenri.py?line=55'>56</a> scrape_return_stats(2022)
#
# /henrifabre123/tennisML/scrapping/scraphenri.py in line 41, in scrape_return_stats(year)
#      <a href='vscode-vfs://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a2264617461227d7d/henrifabre123/tennisML/scrapping/scraphenri.py?line=37'>38</a> data = []
#      <a href='vscode-vfs://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a2264617461227d7d/henrifabre123/tennisML/scrapping/scraphenri.py?line=38'>39</a> for row in table.xpath('.//tbody//tr'):
#      <a href='vscode-vfs://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a2264617461227d7d/henrifabre123/tennisML/scrapping/scraphenri.py?line=39'>40</a>     # Extraire le nom du joueur à partir du lien
# ---> <a href='vscode-vfs://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a2264617461227d7d/henrifabre123/tennisML/scrapping/scraphenri.py?line=40'>41</a>     player_name = row.xpath('.//td[@data-title="Player"]//a[@class="stats-player-name"]/text()')[0].strip()
#      <a href='vscode-vfs://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a2264617461227d7d/henrifabre123/tennisML/scrapping/scraphenri.py?line=42'>43</a>     # Extraire les autres données de la ligne
#      <a href='vscode-vfs://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a2264617461227d7d/henrifabre123/tennisML/scrapping/scraphenri.py?line=43'>44</a>     row_data = [player_name] + [td.text.strip() if td.text else '' for td in row.xpath('.//td')[1:]]  # Ajouter le nom du joueur en première colonne
#
# IndexError: list index out of range

# %%
import time
import requests
from lxml import html
import pandas as pd
from selenium import webdriver

def get_page_content(url, wait_time=10):
    # Utiliser Selenium pour laisser le temps à la page de charger
    driver = webdriver.Chrome()
    driver.get(url)

    # Attendre que la page se charge
    time.sleep(wait_time)

    # Utiliser requests pour obtenir le contenu de la page après le chargement
    page_content = driver.page_source

    # Fermer le navigateur Selenium
    driver.quit()

    return page_content

def scrape_return_stats(year):
    # Construire l'URL avec l'année spécifiée
    url = f'https://www.atptour.com/en/stats/leaderboard?boardType=return&timeFrame={year}&surface=all&versusRank=all&formerNo1=false'

    # Obtenir le contenu de la page
    content = get_page_content(url)

    # Utiliser lxml pour créer un objet ElementTree à partir du contenu de la page
    tree = html.fromstring(content)

    # Utiliser l'XPath pour extraire le tableau
    table = tree.xpath('//div[@id="statsListingTableContent"]/table')[0]



    data = []
    for row in table.xpath('.//tbody//tr'):
        player_name_elements = row.xpath('.//td[2]/div/a[@class="stats-player-name"]/text()')
        player_name = player_name_elements[0].strip() if player_name_elements else 'N/A'
        
        # Extraire les autres données de la ligne
        row_data = [player_name] + [td.text.strip() if td.text else '' for td in row.xpath('.//td')[1:]]  # Ajouter le nom du joueur en première colonne
        print("Row data:", row_data)
        data.append(row_data)

    # Créer un DataFrame Pandas
    df = pd.DataFrame(data, columns=headers)



    return df

# Utilisation de la fonction pour l'année 2022
scrape_return_stats(2022)
# Out:
# Row data: ['Diego Schwartzman', '', '163.5', '35.3%', '54.0%', '31.5%', '42.7%']
# Row data: ['Rafael Nadal', '', '162.6', '34.2%', '53.9%', '31.0%', '43.5%']
# Row data: ['Novak Djokovic', '', '160.1', '33.0%', '56.0%', '28.6%', '42.5%']
# Row data: ['Carlos Alcaraz', '', '158.6', '34.0%', '53.4%', '30.8%', '40.4%']
# Row data: ['Alex de Minaur', '', '158.3', '33.1%', '52.6%', '28.6%', '44.0%']
# Row data: ['Mikael Ymer', '', '158.2', '33.8%', '52.2%', '29.6%', '42.6%']
# Row data: ['Alejandro Tabilo', '', '157.8', '33.2%', '52.1%', '29.0%', '43.5%']
# Row data: ['Daniil Medvedev', '', '154.7', '31.7%', '53.9%', '26.7%', '42.4%']
# Row data: ['Francisco Cerundolo', '', '154.1', '32.7%', '52.4%', '27.6%', '41.4%']
# Row data: ['Alexander Zverev', '', '154.1', '32.7%', '50.0%', '26.1%', '45.3%']
# Row data: ['Cameron Norrie', '', '154.1', '31.1%', '52.6%', '26.7%', '43.7%']
# Row data: ['Jannik Sinner', '', '153.4', '32.3%', '53.0%', '26.7%', '41.4%']
# Row data: ['Jenson Brooksby', '', '151.9', '32.3%', '49.8%', '26.1%', '43.7%']
# Row data: ['Roberto Bautista Agut', '', '151.5', '30.0%', '55.1%', '27.3%', '39.1%']
# Row data: ['Sebastian Korda', '', '150.9', '32.5%', '50.2%', '26.5%', '41.7%']
# Row data: ['Miomir Kecmanovic', '', '150.0', '30.6%', '53.1%', '25.3%', '41.0%']
# Row data: ['Lorenzo Musetti', '', '149.9', '30.0%', '50.0%', '23.6%', '46.3%']
# Row data: ['Federico Coria', '', '149.3', '32.9%', '50.2%', '25.3%', '40.9%']
# Row data: ['Botic van de Zandschulp', '', '148.7', '31.5%', '50.3%', '24.9%', '42.0%']
# Row data: ['Alejandro Davidovich Fokina', '', '148.2', '31.8%', '50.0%', '26.1%', '40.3%']
# Row data: ['Emil Ruusuvuori', '', '148.1', '31.6%', '51.6%', '25.2%', '39.7%']
# Row data: ['Mackenzie McDonald', '', '147.5', '29.9%', '50.8%', '24.2%', '42.6%']
# Row data: ['Sebastian Baez', '', '147.1', '32.5%', '50.8%', '25.2%', '38.6%']
# Row data: ['Daniel Evans', '', '146.9', '30.1%', '51.0%', '24.2%', '41.6%']
# Row data: ['Albert Ramos-Vinolas', '', '146.6', '30.5%', '51.2%', '23.4%', '41.5%']
# Row data: ['Andy Murray', '', '146.1', '28.5%', '54.7%', '23.6%', '39.3%']
# Row data: ['Filip Krajinovic', '', '146.1', '26.6%', '50.3%', '21.7%', '47.5%']
# Row data: ['David Goffin', '', '145.7', '31.7%', '49.8%', '25.3%', '38.9%']
# Row data: ['Cristian Garin', '', '145.3', '31.6%', '49.3%', '24.5%', '39.9%']
# Row data: ['Jaume Munar', '', '145.2', '33.8%', '49.6%', '25.6%', '36.2%']
# Row data: ['Taylor Fritz', '', '144.8', '29.9%', '52.3%', '24.5%', '38.1%']
# Row data: ['Pablo Carreno Busta', '', '144.6', '29.8%', '52.0%', '24.3%', '38.5%']
# Row data: ['Jack Draper', '', '144.5', '27.9%', '52.3%', '23.7%', '40.6%']
# Row data: ['Tommy Paul', '', '144.4', '31.3%', '49.6%', '24.3%', '39.2%']
# Row data: ['Andrey Rublev', '', '144.3', '29.9%', '51.5%', '23.5%', '39.4%']
# Row data: ['Yoshihito Nishioka', '', '143.9', '26.0%', '54.0%', '22.3%', '41.6%']
# Row data: ['Federico Delbonis', '', '143.6', '28.5%', '47.3%', '20.6%', '47.2%']
# Row data: ['Holger Rune', '', '143.3', '29.7%', '50.5%', '22.2%', '40.9%']
# Row data: ['Alex Molcan', '', '142.9', '30.3%', '50.5%', '22.7%', '39.4%']
# Row data: ['Marin Cilic', '', '142.2', '30.7%', '50.1%', '22.8%', '38.6%']
# Row data: ['Ilya Ivashka', '', '141.9', '28.9%', '48.5%', '22.3%', '42.2%']
# Row data: ['Fabio Fognini', '', '141.7', '28.8%', '50.6%', '23.6%', '38.7%']
# Row data: ['Taro Daniel', '', '141.6', '29.9%', '49.3%', '21.2%', '41.2%']
# Row data: ['Stefanos Tsitsipas', '', '141.2', '28.6%', '49.9%', '21.2%', '41.5%']
# Row data: ['Richard Gasquet', '', '140.8', '28.6%', '50.9%', '22.5%', '38.8%']
# Row data: ['Aslan Karatsev', '', '140.8', '30.3%', '49.3%', '22.1%', '39.1%']
# Row data: ['Grigor Dimitrov', '', '140.7', '30.0%', '49.6%', '22.2%', '38.9%']
# Row data: ['Pedro Martinez', '', '139.9', '31.1%', '50.7%', '23.0%', '35.1%']
# Row data: ['Casper Ruud', '', '139.7', '29.4%', '50.3%', '22.6%', '37.4%']
# Row data: ['Soonwoo Kwon', '', '138.2', '26.4%', '51.4%', '21.4%', '39.0%']
# Row data: ['Karen Khachanov', '', '138.1', '28.2%', '48.9%', '20.2%', '40.8%']
# Row data: ['Lorenzo Sonego', '', '138.0', '30.7%', '45.4%', '20.3%', '41.6%']
# Row data: ['Joao Sousa', '', '138.0', '30.1%', '50.1%', '21.6%', '36.2%']
# Row data: ['Felix Auger-Aliassime', '', '137.7', '31.1%', '47.9%', '21.0%', '37.7%']
# Row data: ['Nick Kyrgios', '', '136.7', '26.9%', '47.7%', '19.5%', '42.6%']
# Row data: ['Benjamin Bonzi', '', '135.4', '27.3%', '50.9%', '19.6%', '37.6%']
# Row data: ['Alexander Bublik', '', '135.4', '30.4%', '45.8%', '19.7%', '39.5%']
# Row data: ['Frances Tiafoe', '', '134.4', '26.4%', '51.1%', '18.8%', '38.1%']
# Row data: ['Dominic Thiem', '', '134.2', '29.3%', '47.8%', '18.7%', '38.4%']
# Row data: ['Oscar Otte', '', '134.1', '28.0%', '47.8%', '19.7%', '38.6%']
# Row data: ['Laslo Djere', '', '134.0', '26.7%', '46.9%', '20.3%', '40.1%']
# Row data: ['Brandon Nakashima', '', '133.6', '27.5%', '49.3%', '18.5%', '38.3%']
# Row data: ['Adrian Mannarino', '', '133.0', '27.5%', '50.9%', '19.6%', '35.0%']
# Row data: ['Marton Fucsovics', '', '132.2', '28.8%', '48.7%', '19.0%', '35.7%']
# Row data: ['Jiri Lehecka', '', '130.8', '27.4%', '45.9%', '18.5%', '39.0%']
# Row data: ['Thiago Monteiro', '', '130.8', '24.7%', '47.9%', '16.5%', '41.7%']
# Row data: ['Hubert Hurkacz', '', '130.6', '27.0%', '47.7%', '17.9%', '38.0%']
# Row data: ['Roman Safiullin', '', '130.2', '26.8%', '51.7%', '19.5%', '32.2%']
# Row data: ['Dusan Lajovic', '', '130.1', '28.1%', '48.3%', '18.8%', '34.9%']
# Row data: ['Marcos Giron', '', '129.7', '26.9%', '46.0%', '17.3%', '39.5%']
# Row data: ['Denis Shapovalov', '', '129.5', '27.6%', '47.7%', '18.3%', '35.9%']
# Row data: ['Ugo Humbert', '', '128.2', '28.0%', '46.8%', '16.9%', '36.5%']
# Row data: ['Matteo Berrettini', '', '128.1', '28.7%', '44.5%', '17.9%', '37.0%']
# Row data: ['Max Purcell', '', '126.7', '26.6%', '48.4%', '20.0%', '31.7%']
# Row data: ['Nikoloz Basilashvili', '', '125.3', '24.8%', '49.0%', '15.7%', '35.8%']
# Row data: ['Sebastian Ofner', '', '125.0', '25.8%', '46.1%', '16.3%', '36.8%']
# Row data: ['Borna Coric', '', '124.2', '26.1%', '48.9%', '16.1%', '33.1%']
# Row data: ['Alexander Shevchenko', '', '124.2', '24.3%', '49.2%', '14.3%', '36.4%']
# Row data: ['Stan Wawrinka', '', '122.6', '25.7%', '45.3%', '14.9%', '36.7%']
# Row data: ['Tallon Griekspoor', '', '120.9', '24.3%', '49.9%', '15.2%', '31.5%']
# Row data: ['Christopher Eubanks', '', '120.4', '22.4%', '42.0%', '10.8%', '45.2%']
# Row data: ['Tomas Martin Etcheverry', '', '119.6', '24.8%', '44.2%', '14.0%', '36.6%']
# Row data: ['Maxime Cressy', '', '119.4', '24.3%', '42.0%', '13.2%', '39.9%']
# Row data: ['Ben Shelton', '', '119.4', '25.5%', '43.4%', '12.6%', '37.9%']
# Row data: ['Arthur Rinderknech', '', '117.4', '24.0%', '45.1%', '13.8%', '34.5%']
# Row data: ['Arthur Fils', '', '116.1', '29.0%', '41.3%', '12.5%', '33.3%']
# Row data: ['Jan-Lennard Struff', '', '115.8', '24.4%', '49.2%', '12.3%', '29.9%']
# Row data: ['Steve Johnson', '', '114.5', '22.9%', '47.4%', '12.9%', '31.3%']
# Row data: ['Alexei Popyrin', '', '108.8', '24.1%', '46.2%', '12.4%', '26.1%']
# Row data: ['Matteo Arnaldi', '', '106.3', '23.9%', '46.8%', '12.5%', '23.1%']
# Row data: ['Reilly Opelka', '', '105.4', '21.5%', '42.3%', '10.9%', '30.7%']
# Row data: ['John Isner', '', '96.7', '21.1%', '38.9%', '7.6%', '29.1%']
# Row data: ['Nicolas Jarry', '', '80.5', '21.2%', '38.7%', '5.0%', '15.6%']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /henrifabre123/tennisML/scrapping/scraphenri.py in line 56
#      <a href='vscode-vfs://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a2264617461227d7d/henrifabre123/tennisML/scrapping/scraphenri.py?line=52'>53</a>     return df
#      <a href='vscode-vfs://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a2264617461227d7d/henrifabre123/tennisML/scrapping/scraphenri.py?line=54'>55</a> # Utilisation de la fonction pour l'année 2022
# ---> <a href='vscode-vfs://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a2264617461227d7d/henrifabre123/tennisML/scrapping/scraphenri.py?line=55'>56</a> scrape_return_stats(2022)
#
# /henrifabre123/tennisML/scrapping/scraphenri.py in line 49, in scrape_return_stats(year)
#      <a href='vscode-vfs://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a2264617461227d7d/henrifabre123/tennisML/scrapping/scraphenri.py?line=45'>46</a>     data.append(row_data)
#      <a href='vscode-vfs://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a2264617461227d7d/henrifabre123/tennisML/scrapping/scraphenri.py?line=47'>48</a> # Créer un DataFrame Pandas
# ---> <a href='vscode-vfs://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a2264617461227d7d/henrifabre123/tennisML/scrapping/scraphenri.py?line=48'>49</a> df = pd.DataFrame(data, columns=headers)
#      <a href='vscode-vfs://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a2264617461227d7d/henrifabre123/tennisML/scrapping/scraphenri.py?line=52'>53</a> return df
#
# NameError: name 'headers' is not defined

# %%
import time
import requests
from lxml import html
import pandas as pd
from selenium import webdriver

def get_page_content(url, wait_time=10):
    # Utiliser Selenium pour laisser le temps à la page de charger
    driver = webdriver.Chrome()
    driver.get(url)

    # Attendre que la page se charge
    time.sleep(wait_time)

    # Utiliser requests pour obtenir le contenu de la page après le chargement
    page_content = driver.page_source

    # Fermer le navigateur Selenium
    driver.quit()

    return page_content

def scrape_return_stats(year):
    # Construire l'URL avec l'année spécifiée
    url = f'https://www.atptour.com/en/stats/leaderboard?boardType=return&timeFrame={year}&surface=all&versusRank=all&formerNo1=false'

    # Obtenir le contenu de la page
    content = get_page_content(url)

    # Utiliser lxml pour créer un objet ElementTree à partir du contenu de la page
    tree = html.fromstring(content)

    # Utiliser l'XPath pour extraire le tableau
    table = tree.xpath('//div[@id="statsListingTableContent"]/table')[0]



    data = []
    for row in table.xpath('.//tbody//tr'):
        player_name_elements = row.xpath('.//td[2]/div/a[@class="stats-player-name"]/text()')
        player_name = player_name_elements[0].strip() if player_name_elements else 'N/A'
        
        # Extraire les autres données de la ligne
        row_data = [player_name] + [td.text.strip() if td.text else '' for td in row.xpath('.//td')[1:]]  # Ajouter le nom du joueur en première colonne
        print("Row data:", row_data)
        data.append(row_data)

    # Créer un DataFrame Pandas
    df = pd.DataFrame(data, columns = ['Name',' ','Return Rating','% 1 Serve Return Points Won','% 2nd Serve Return Points Won','% Return Games Won','% Break Points Converted'])



    return df

# Utilisation de la fonction pour l'année 2022
scrape_return_stats(2022)
# Out:
# Row data: ['Diego Schwartzman', '', '163.5', '35.3%', '54.0%', '31.5%', '42.7%']
# Row data: ['Rafael Nadal', '', '162.6', '34.2%', '53.9%', '31.0%', '43.5%']
# Row data: ['Novak Djokovic', '', '160.1', '33.0%', '56.0%', '28.6%', '42.5%']
# Row data: ['Carlos Alcaraz', '', '158.6', '34.0%', '53.4%', '30.8%', '40.4%']
# Row data: ['Alex de Minaur', '', '158.3', '33.1%', '52.6%', '28.6%', '44.0%']
# Row data: ['Mikael Ymer', '', '158.2', '33.8%', '52.2%', '29.6%', '42.6%']
# Row data: ['Alejandro Tabilo', '', '157.8', '33.2%', '52.1%', '29.0%', '43.5%']
# Row data: ['Daniil Medvedev', '', '154.7', '31.7%', '53.9%', '26.7%', '42.4%']
# Row data: ['Francisco Cerundolo', '', '154.1', '32.7%', '52.4%', '27.6%', '41.4%']
# Row data: ['Alexander Zverev', '', '154.1', '32.7%', '50.0%', '26.1%', '45.3%']
# Row data: ['Cameron Norrie', '', '154.1', '31.1%', '52.6%', '26.7%', '43.7%']
# Row data: ['Jannik Sinner', '', '153.4', '32.3%', '53.0%', '26.7%', '41.4%']
# Row data: ['Jenson Brooksby', '', '151.9', '32.3%', '49.8%', '26.1%', '43.7%']
# Row data: ['Roberto Bautista Agut', '', '151.5', '30.0%', '55.1%', '27.3%', '39.1%']
# Row data: ['Sebastian Korda', '', '150.9', '32.5%', '50.2%', '26.5%', '41.7%']
# Row data: ['Miomir Kecmanovic', '', '150.0', '30.6%', '53.1%', '25.3%', '41.0%']
# Row data: ['Lorenzo Musetti', '', '149.9', '30.0%', '50.0%', '23.6%', '46.3%']
# Row data: ['Federico Coria', '', '149.3', '32.9%', '50.2%', '25.3%', '40.9%']
# Row data: ['Botic van de Zandschulp', '', '148.7', '31.5%', '50.3%', '24.9%', '42.0%']
# Row data: ['Alejandro Davidovich Fokina', '', '148.2', '31.8%', '50.0%', '26.1%', '40.3%']
# Row data: ['Emil Ruusuvuori', '', '148.1', '31.6%', '51.6%', '25.2%', '39.7%']
# Row data: ['Mackenzie McDonald', '', '147.5', '29.9%', '50.8%', '24.2%', '42.6%']
# Row data: ['Sebastian Baez', '', '147.1', '32.5%', '50.8%', '25.2%', '38.6%']
# Row data: ['Daniel Evans', '', '146.9', '30.1%', '51.0%', '24.2%', '41.6%']
# Row data: ['Albert Ramos-Vinolas', '', '146.6', '30.5%', '51.2%', '23.4%', '41.5%']
# Row data: ['Andy Murray', '', '146.1', '28.5%', '54.7%', '23.6%', '39.3%']
# Row data: ['Filip Krajinovic', '', '146.1', '26.6%', '50.3%', '21.7%', '47.5%']
# Row data: ['David Goffin', '', '145.7', '31.7%', '49.8%', '25.3%', '38.9%']
# Row data: ['Cristian Garin', '', '145.3', '31.6%', '49.3%', '24.5%', '39.9%']
# Row data: ['Jaume Munar', '', '145.2', '33.8%', '49.6%', '25.6%', '36.2%']
# Row data: ['Taylor Fritz', '', '144.8', '29.9%', '52.3%', '24.5%', '38.1%']
# Row data: ['Pablo Carreno Busta', '', '144.6', '29.8%', '52.0%', '24.3%', '38.5%']
# Row data: ['Jack Draper', '', '144.5', '27.9%', '52.3%', '23.7%', '40.6%']
# Row data: ['Tommy Paul', '', '144.4', '31.3%', '49.6%', '24.3%', '39.2%']
# Row data: ['Andrey Rublev', '', '144.3', '29.9%', '51.5%', '23.5%', '39.4%']
# Row data: ['Yoshihito Nishioka', '', '143.9', '26.0%', '54.0%', '22.3%', '41.6%']
# Row data: ['Federico Delbonis', '', '143.6', '28.5%', '47.3%', '20.6%', '47.2%']
# Row data: ['Holger Rune', '', '143.3', '29.7%', '50.5%', '22.2%', '40.9%']
# Row data: ['Alex Molcan', '', '142.9', '30.3%', '50.5%', '22.7%', '39.4%']
# Row data: ['Marin Cilic', '', '142.2', '30.7%', '50.1%', '22.8%', '38.6%']
# Row data: ['Ilya Ivashka', '', '141.9', '28.9%', '48.5%', '22.3%', '42.2%']
# Row data: ['Fabio Fognini', '', '141.7', '28.8%', '50.6%', '23.6%', '38.7%']
# Row data: ['Taro Daniel', '', '141.6', '29.9%', '49.3%', '21.2%', '41.2%']
# Row data: ['Stefanos Tsitsipas', '', '141.2', '28.6%', '49.9%', '21.2%', '41.5%']
# Row data: ['Richard Gasquet', '', '140.8', '28.6%', '50.9%', '22.5%', '38.8%']
# Row data: ['Aslan Karatsev', '', '140.8', '30.3%', '49.3%', '22.1%', '39.1%']
# Row data: ['Grigor Dimitrov', '', '140.7', '30.0%', '49.6%', '22.2%', '38.9%']
# Row data: ['Pedro Martinez', '', '139.9', '31.1%', '50.7%', '23.0%', '35.1%']
# Row data: ['Casper Ruud', '', '139.7', '29.4%', '50.3%', '22.6%', '37.4%']
# Row data: ['Soonwoo Kwon', '', '138.2', '26.4%', '51.4%', '21.4%', '39.0%']
# Row data: ['Karen Khachanov', '', '138.1', '28.2%', '48.9%', '20.2%', '40.8%']
# Row data: ['Lorenzo Sonego', '', '138.0', '30.7%', '45.4%', '20.3%', '41.6%']
# Row data: ['Joao Sousa', '', '138.0', '30.1%', '50.1%', '21.6%', '36.2%']
# Row data: ['Felix Auger-Aliassime', '', '137.7', '31.1%', '47.9%', '21.0%', '37.7%']
# Row data: ['Nick Kyrgios', '', '136.7', '26.9%', '47.7%', '19.5%', '42.6%']
# Row data: ['Benjamin Bonzi', '', '135.4', '27.3%', '50.9%', '19.6%', '37.6%']
# Row data: ['Alexander Bublik', '', '135.4', '30.4%', '45.8%', '19.7%', '39.5%']
# Row data: ['Frances Tiafoe', '', '134.4', '26.4%', '51.1%', '18.8%', '38.1%']
# Row data: ['Dominic Thiem', '', '134.2', '29.3%', '47.8%', '18.7%', '38.4%']
# Row data: ['Oscar Otte', '', '134.1', '28.0%', '47.8%', '19.7%', '38.6%']
# Row data: ['Laslo Djere', '', '134.0', '26.7%', '46.9%', '20.3%', '40.1%']
# Row data: ['Brandon Nakashima', '', '133.6', '27.5%', '49.3%', '18.5%', '38.3%']
# Row data: ['Adrian Mannarino', '', '133.0', '27.5%', '50.9%', '19.6%', '35.0%']
# Row data: ['Marton Fucsovics', '', '132.2', '28.8%', '48.7%', '19.0%', '35.7%']
# Row data: ['Jiri Lehecka', '', '130.8', '27.4%', '45.9%', '18.5%', '39.0%']
# Row data: ['Thiago Monteiro', '', '130.8', '24.7%', '47.9%', '16.5%', '41.7%']
# Row data: ['Hubert Hurkacz', '', '130.6', '27.0%', '47.7%', '17.9%', '38.0%']
# Row data: ['Roman Safiullin', '', '130.2', '26.8%', '51.7%', '19.5%', '32.2%']
# Row data: ['Dusan Lajovic', '', '130.1', '28.1%', '48.3%', '18.8%', '34.9%']
# Row data: ['Marcos Giron', '', '129.7', '26.9%', '46.0%', '17.3%', '39.5%']
# Row data: ['Denis Shapovalov', '', '129.5', '27.6%', '47.7%', '18.3%', '35.9%']
# Row data: ['Ugo Humbert', '', '128.2', '28.0%', '46.8%', '16.9%', '36.5%']
# Row data: ['Matteo Berrettini', '', '128.1', '28.7%', '44.5%', '17.9%', '37.0%']
# Row data: ['Max Purcell', '', '126.7', '26.6%', '48.4%', '20.0%', '31.7%']
# Row data: ['Nikoloz Basilashvili', '', '125.3', '24.8%', '49.0%', '15.7%', '35.8%']
# Row data: ['Sebastian Ofner', '', '125.0', '25.8%', '46.1%', '16.3%', '36.8%']
# Row data: ['Borna Coric', '', '124.2', '26.1%', '48.9%', '16.1%', '33.1%']
# Row data: ['Alexander Shevchenko', '', '124.2', '24.3%', '49.2%', '14.3%', '36.4%']
# Row data: ['Stan Wawrinka', '', '122.6', '25.7%', '45.3%', '14.9%', '36.7%']
# Row data: ['Tallon Griekspoor', '', '120.9', '24.3%', '49.9%', '15.2%', '31.5%']
# Row data: ['Christopher Eubanks', '', '120.4', '22.4%', '42.0%', '10.8%', '45.2%']
# Row data: ['Tomas Martin Etcheverry', '', '119.6', '24.8%', '44.2%', '14.0%', '36.6%']
# Row data: ['Maxime Cressy', '', '119.4', '24.3%', '42.0%', '13.2%', '39.9%']
# Row data: ['Ben Shelton', '', '119.4', '25.5%', '43.4%', '12.6%', '37.9%']
# Row data: ['Arthur Rinderknech', '', '117.4', '24.0%', '45.1%', '13.8%', '34.5%']
# Row data: ['Arthur Fils', '', '116.1', '29.0%', '41.3%', '12.5%', '33.3%']
# Row data: ['Jan-Lennard Struff', '', '115.8', '24.4%', '49.2%', '12.3%', '29.9%']
# Row data: ['Steve Johnson', '', '114.5', '22.9%', '47.4%', '12.9%', '31.3%']
# Row data: ['Alexei Popyrin', '', '108.8', '24.1%', '46.2%', '12.4%', '26.1%']
# Row data: ['Matteo Arnaldi', '', '106.3', '23.9%', '46.8%', '12.5%', '23.1%']
# Row data: ['Reilly Opelka', '', '105.4', '21.5%', '42.3%', '10.9%', '30.7%']
# Row data: ['John Isner', '', '96.7', '21.1%', '38.9%', '7.6%', '29.1%']
# Row data: ['Nicolas Jarry', '', '80.5', '21.2%', '38.7%', '5.0%', '15.6%']
#                  Name    Return Rating % 1 Serve Return Points Won  \
# 0   Diego Schwartzman            163.5                       35.3%
# 1        Rafael Nadal            162.6                       34.2%
# 2      Novak Djokovic            160.1                       33.0%
# 3      Carlos Alcaraz            158.6                       34.0%
# 4      Alex de Minaur            158.3                       33.1%
# ..                ... ..           ...                         ...
# 88     Alexei Popyrin            108.8                       24.1%
# 89     Matteo Arnaldi            106.3                       23.9%
# 90      Reilly Opelka            105.4                       21.5%
# 91         John Isner             96.7                       21.1%
# 92      Nicolas Jarry             80.5                       21.2%
#
#    % 2nd Serve Return Points Won % Return Games Won % Break Points Converted
# 0                          54.0%              31.5%                    42.7%
# 1                          53.9%              31.0%                    43.5%
# 2                          56.0%              28.6%                    42.5%
# 3                          53.4%              30.8%                    40.4%
# 4                          52.6%              28.6%                    44.0%
# ..                           ...                ...                      ...
# 88                         46.2%              12.4%                    26.1%
# 89                         46.8%              12.5%                    23.1%
# 90                         42.3%              10.9%                    30.7%
# 91                         38.9%               7.6%                    29.1%
# 92                         38.7%               5.0%                    15.6%
#
# [93 rows x 7 columns]
