# %% [markdown]
# Dans cette partie de code, nous voulons créer un dataframe qui correspond aux informations des joueurs regroupées par années.

# %%
import pandas as pd

# %%
path='.\Data\Data_utiles\info_matches.csv'
info_matches=pd.read_csv(path)

# %%
joueurs_dict = {}


for index, row in info_matches.iterrows():

    winner_id = row['winner_id']
    loser_id = row['loser_id']

    
    if winner_id not in joueurs_dict:
        joueurs_dict[winner_id] = {'name': row['winner_name'],'hand': row['winner_hand'],'height': row['winner_ht']}

    if loser_id not in joueurs_dict:
        joueurs_dict[loser_id] = {'name': row['loser_name'],'hand': row['loser_hand'],'height': row['loser_ht']}

print(joueurs_dict)
# Out:
# {101990: {'name': 'Richard Krajicek', 'hand': 'R', 'height': 196.0}, 102358: {'name': 'Thomas Enqvist', 'hand': 'R', 'height': 190.0}, 101890: {'name': 'Jonathan Stark', 'hand': 'R', 'height': 188.0}, 101889: {'name': 'Todd Woodbridge', 'hand': 'R', 'height': 178.0}, 102146: {'name': 'Jordi Burillo', 'hand': 'R', 'height': 188.0}, 101609: {'name': 'David Wheaton', 'hand': 'R', 'height': 193.0}, 101334: {'name': 'Alexander Volkov', 'hand': 'L', 'height': 188.0}, 101298: {'name': 'Jonas Svensson', 'hand': 'R', 'height': 188.0}, 101685: {'name': 'Markus Naewie', 'hand': 'R', 'height': 190.0}, 102417: {'name': 'Steven Baldas', 'hand': 'R', 'height': 180.0}, 101920: {'name': 'Jamie Morgan', 'hand': 'R', 'height': 185.0}, 101463: {'name': 'Bernd Karbacher', 'hand': 'R', 'height': 185.0}, 101900: {'name': 'Nicklas Kulti', 'hand': 'R', 'height': 190.0}, 101185: {'name': 'Mark Woodforde', 'hand': 'L', 'height': 188.0}, 101196: {'name': 'Derrick Rostagno', 'hand': 'R', 'height': 185.0}, 101723: {'name': 'Magnus Larsson', 'hand': 'R', 'height': 193.0}, 101377: {'name': 'Christian Bergstrom', 'hand': 'R', 'height': 180.0}, 102202: {'name': 'Kenneth Carlsen', 'hand': 'L', 'height': 190.0}, 101774: {'name': 'Todd Martin', 'hand': 'R', 'height': 198.0}, 101214: {'name': 'Bryan Shelton', 'hand': 'R', 'height': 185.0}, 101611: {'name': 'Cedric Pioline', 'hand': 'R', 'height': 188.0}, 101776: {'name': 'Sandon Stolle', 'hand': 'R', 'height': 193.0}, 101735: {'name': 'Richard Fromberg', 'hand': 'R', 'height': 196.0}, 101320: {'name': 'Magnus Gustafsson', 'hand': 'R', 'height': 185.0}, 101727: {'name': 'Jason Stoltenberg', 'hand': 'R', 'height': 185.0}, 102154: {'name': 'Marcos Ondruska', 'hand': 'R', 'height': 183.0}, 